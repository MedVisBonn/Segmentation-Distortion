# %%
import matplotlib.pyplot as plt
import wandb
from tqdm.auto import tqdm
import os, sys
import time
import numpy as np
import collections
import torch
from torch import Tensor, nn
from torch.utils.data import Dataset, DataLoader
from torch import optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.cuda.amp import autocast, GradScaler
from torchvision.transforms import Resize, CenterCrop
from typing import Iterable, Dict, Callable, Tuple
import torch.nn.functional as F
import matplotlib.pyplot as plt
from random import randrange

from nnunet.training.model_restore import restore_model
import batchgenerators
from batchgenerators.transforms.local_transforms import *
from batchgenerators.dataloading.single_threaded_augmenter import SingleThreadedAugmenter
from batchgenerators.dataloading.multi_threaded_augmenter import MultiThreadedAugmenter
from batchgenerators.utilities.file_and_folder_operations import *
from nnunet.paths import preprocessing_output_dir
from nnunet.training.dataloading.dataset_loading import *
from nnunet.training.network_training.nnUNetTrainerV2 import nnUNetTrainerV2
from nnunet.run.load_pretrained_weights import load_pretrained_weights

sys.path.append('../..')
from dataset import CalgaryCampinasDataset, ACDCDataset, MNMDataset
from augment import SingleImageMultiViewDataLoader, MultiImageSingleViewDataLoader
from utils import EarlyStopping, epoch_average, average_metrics
from model.dae import AugResDAE
from model.unet import UNet2D
from model.wrapper import ModelAdapter
from losses import MNMCriterionAE, SampleDice, UnetDice
from trainer.ae_trainer import AETrainerACDCV2
from augment import nnUNet_train_augmentations

# %%
train_augmentor = batchgenerators.transforms.abstract_transforms.Compose(nnUNet_train_augmentations)

# %%
data_path = '../../../data/conp-dataset/projects/calgary-campinas/CC359/Reconstructed/'

trainset = CalgaryCampinasDataset(
    data_path=data_path, 
    site=6,
    split='train',
    augment=False, 
    normalize=True, 
    debug=True
)

# %%
dataloader = MultiImageSingleViewDataLoader(data=trainset, batch_size=2, return_orig=False)

# %%
train_gen = MultiThreadedAugmenter(dataloader, train_augmentor, 4, 2, seeds=None)

# %%
tmp = next(train_gen)

# %%
tmp['data'].mean()
# Out:
# tensor(-0.2401)

# %%
trainset[0]['input'].shape
# Out:
# torch.Size([1, 256, 256])

# %%
dataloader.generate_train_batch()['data'].shape
# Out:
# (2, 1, 256, 256)

# %%
it = 0
residual = True

cfg = {
    'debug': False,
    'log': True,
    'description': f'acdc_AugResDAE{it}_localAug_multiImgSingleView_{"res" if residual else "recon"}_balanced_same', #'mms_vae_for_nnUNet_fc3_0_bs50',
    'project': 'MICCAI2023-loose_ends',

    # Data params
    'n': 0,
    'root': '../../',
    'data_path': 'data/mnm/',
    'unet': f'acdc_unet8_{it}',
    'channel_out': 8,

    # Hyperparams
    'batch_size': 32,
    'lr': 1e-4,
    'augment': False,
    'difference': True,
    'loss': 'huber',  # huber or ce
    'target': 'output', #gt or output
    'reconstruction': True,
    'augmentations': 'local',
    'disabled_ids': ['shortcut0', 'shortcut1', 'shortcut2'], #['shortcut0', 'shortcut1', 'shortcut2']
}

nnUnet_prefix = '../../../../nnUNet/'

description = cfg['description']
root = cfg['root']

# # Unet
# unet_path = cfg['unet'] # + str(cfg['n'])
# unet = UNet2D(n_chans_in=1, n_chans_out=4, n_filters_init=cfg['channel_out']).cuda()
# model_path = f'{root}pre-trained-tmp/trained_UNets/{unet_path}_best.pt'
# state_dict = torch.load(model_path)['model_state_dict']
# unet.load_state_dict(state_dict)

### Dataloader
## Initialize trainer to get data loaders with data augmentations from training
pkl_file          = nnUnet_prefix + 'data/nnUNet_preprocessed/Task500_ACDC/nnUNetPlansv2.1_plans_2D.pkl'
fold              = 0
output_folder     = nnUnet_prefix + 'results/nnUnet/nnUNet/2d/Task027_ACDC/nnUNetTrainerV2__nnUNetPlansv2.1/'
dataset_directory = nnUnet_prefix + 'data/nnUNet_preprocessed/Task500_ACDC'

trainer = nnUNetTrainerV2(pkl_file, 0, output_folder, dataset_directory)
trainer.initialize()

train_loader = trainer.tr_gen
valid_loader = trainer.val_gen



if cfg['augmentations'] == 'all':
    train_transforms = [t for t in train_loader.transform.transforms]
    valid_transforms = [t for t in valid_loader.transform.transforms]

elif cfg['augmentations'] == 'output_invariant':
    data_only_transforms = (
        batchgenerators.transforms.resample_transforms.SimulateLowResolutionTransform,
        batchgenerators.transforms.noise_transforms.GaussianNoiseTransform,
        batchgenerators.transforms.noise_transforms.GaussianBlurTransform,
        batchgenerators.transforms.color_transforms.BrightnessMultiplicativeTransform,
        batchgenerators.transforms.color_transforms.ContrastAugmentationTransform,
        batchgenerators.transforms.color_transforms.GammaTransform,
        batchgenerators.transforms.utility_transforms.RemoveLabelTransform,
        batchgenerators.transforms.utility_transforms.RenameTransform,
        batchgenerators.transforms.utility_transforms.NumpyToTensor
    )

    train_transforms = [t for t in train_loader.transform.transforms if isinstance(t, data_only_transforms)]
    valid_transforms = [t for t in valid_loader.transform.transforms if isinstance(t, data_only_transforms)]

elif cfg['augmentations'] == 'local':
    original_transforms = (
        batchgenerators.transforms.resample_transforms.SimulateLowResolutionTransform,
        batchgenerators.transforms.noise_transforms.GaussianNoiseTransform,
        batchgenerators.transforms.utility_transforms.RemoveLabelTransform,
        batchgenerators.transforms.utility_transforms.RenameTransform,
        batchgenerators.transforms.utility_transforms.NumpyToTensor
    )

    scale = 200.
    local_transforms = [
        BrightnessGradientAdditiveTransform(scale=scale, max_strength=4, p_per_sample=0.2, p_per_channel=1),
        LocalGammaTransform(scale=scale, gamma=(2, 5), p_per_sample=0.2, p_per_channel=1),
        LocalSmoothingTransform(scale=scale, smoothing_strength=(0.5, 1), p_per_sample=0.2, p_per_channel=1),
        LocalContrastTransform(scale=scale, new_contrast=(1, 3), p_per_sample=0.2, p_per_channel=1),
    ]

    train_transforms = local_transforms + [t for t in train_loader.transform.transforms if isinstance(t, original_transforms)]
    valid_transforms = local_transforms + [t for t in valid_loader.transform.transforms if isinstance(t, original_transforms)]

train_augmentor = batchgenerators.transforms.abstract_transforms.Compose(train_transforms)
valid_augmentor = batchgenerators.transforms.abstract_transforms.Compose(valid_transforms)
### - Load dataset and init batch generator
train_data = ACDCDataset(data='train', debug=False, root='../../../../')
valid_data = ACDCDataset(data='val', debug=False, root='../../../../')

train_gen = MultiImageSingleViewDataLoader(train_data, batch_size=cfg['batch_size'], return_orig=True)
#train_gen = SingleThreadedAugmenter(train_gen, train_augmentor)
train_gen = MultiThreadedAugmenter(train_gen, train_augmentor, 4, 2, seeds=None)
valid_gen = MultiImageSingleViewDataLoader(valid_data, batch_size=cfg['batch_size'], return_orig=True)
#valid_gen = SingleThreadedAugmenter(valid_gen, valid_augmentor)
valid_gen = MultiThreadedAugmenter(valid_gen, valid_augmentor, 4, 2, seeds=None)
# Out:
# loading dataset
# loading all case properties
# 2023-11-27 17:23:28.671876: Using splits from existing split file: ../../../../nnUNet/data/nnUNet_preprocessed/Task500_ACDC/splits_final.pkl
# 2023-11-27 17:23:28.692560: The split file contains 5 splits.
# 2023-11-27 17:23:28.692713: Desired fold for training: 0
# 2023-11-27 17:23:28.693316: This split has 160 training and 40 validation cases.
# unpacking dataset
# done
# loading dataset
# loading all case properties
# loading dataset
# loading all case properties

# %%
pkl_file
# Out:
# '../../../../nnUNet/data/nnUNet_preprocessed/Task500_ACDC/nnUNetPlansv2.1_plans_2D.pkl'

# %%
import pickle

# %%
pickle.load(open(pkl_file, "rb"))
# Out:
# {'num_stages': 1,
#  'num_modalities': 1,
#  'modalities': {0: 'MRI'},
#  'normalization_schemes': OrderedDict([(0, 'nonCT')]),
#  'dataset_properties': {'all_sizes': [(10, 256, 216),
#    (10, 256, 216),
#    (10, 256, 231),
#    (10, 256, 231),
#    (10, 255, 256),
#    (10, 255, 256),
#    (10, 256, 232),
#    (10, 256, 232),
#    (10, 216, 255),
#    (10, 216, 255),
#    (11, 256, 231),
#    (11, 256, 231),
#    (10, 223, 222),
#    (10, 223, 222),
#    (10, 256, 199),
#    (10, 256, 199),
#    (10, 256, 208),
#    (10, 256, 208),
#    (10, 256, 208),
#    (10, 256, 208),
#    (9, 256, 216),
#    (9, 256, 216),
#    (10, 256, 184),
#    (10, 256, 184),
#    (10, 256, 216),
#    (10, 256, 216),
#    (10, 216, 256),
#    (10, 216, 256),
#    (9, 216, 256),
#    (9, 216, 256),
#    (10, 256, 192),
#    (10, 256, 192),
#    (9, 256, 216),
#    (9, 256, 216),
#    (8, 256, 216),
#    (8, 256, 216),
#    (11, 256, 216),
#    (11, 256, 216),
#    (8, 256, 208),
#    (8, 256, 208),
#    (10, 255, 240),
#    (10, 255, 240),
#    (7, 256, 200),
#    (7, 256, 200),
#    (9, 256, 216),
#    (9, 256, 216),
#    (8, 256, 207),
#    (8, 256, 207),
#    (9, 255, 256),
#    (9, 255, 256),
#    (10, 255, 216),
#    (10, 255, 216),
#    (10, 256, 216),
#    (10, 256, 216),
#    (10, 255, 224),
#    (10, 255, 224),
#    (11, 255, 192),
#    (11, 255, 192),
#    (10, 256, 215),
#    (10, 256, 215),
#    (10, 256, 216),
#    (10, 256, 216),
#    (10, 254, 240),
#    (10, 254, 240),
#    (10, 256, 216),
#    (10, 256, 216),
#    (10, 256, 224),
#    (10, 256, 224),
#    (13, 256, 208),
#    (13, 256, 208),
#    (8, 256, 216),
#    (8, 256, 216),
#    (7, 256, 216),
#    (7, 256, 216),
#    (8, 384, 276),
#    (8, 384, 276),
#    (9, 256, 208),
#    (9, 256, 208),
#    (10, 256, 208),
#    (10, 256, 208),
#    (6, 224, 154),
#    (6, 224, 154),
#    (9, 256, 231),
#    (9, 256, 231),
#    (12, 224, 174),
#    (12, 224, 174),
#    (9, 216, 256),
#    (9, 216, 256),
#    (8, 256, 208),
#    (8, 256, 208),
#    (9, 216, 256),
#    (9, 216, 256),
#    (9, 208, 256),
#    (9, 208, 256),
#    (8, 256, 208),
#    (8, 256, 208),
#    (7, 216, 256),
#    (7, 216, 256),
#    (10, 256, 248),
#    (10, 256, 248),
#    (10, 256, 224),
#    (10, 256, 224),
#    (8, 256, 216),
#    (8, 256, 216),
#    (7, 256, 216),
#    (7, 256, 216),
#    (8, 256, 216),
#    (8, 256, 216),
#    (9, 216, 256),
#    (9, 216, 256),
#    (9, 256, 216),
#    (9, 256, 216),
#    (8, 512, 428),
#    (8, 512, 428),
#    (9, 256, 216),
#    (9, 256, 216),
#    (9, 216, 256),
#    (9, 216, 256),
#    (9, 256, 216),
#    (9, 256, 216),
#    (9, 256, 215),
#    (9, 256, 215),
#    (10, 216, 256),
#    (10, 216, 256),
#    (8, 176, 256),
#    (8, 176, 256),
#    (10, 256, 216),
#    (10, 256, 216),
#    (8, 224, 209),
#    (8, 224, 209),
#    (9, 256, 240),
#    (9, 256, 240),
#    (10, 216, 255),
#    (10, 216, 255),
#    (7, 208, 256),
#    (7, 208, 256),
#    (7, 256, 216),
#    (7, 256, 216),
#    (6, 256, 208),
#    (6, 256, 208),
#    (10, 256, 192),
#    (10, 256, 192),
#    (8, 256, 216),
#    (8, 256, 216),
#    (7, 256, 208),
#    (7, 256, 208),
#    (8, 256, 256),
#    (8, 256, 256),
#    (14, 224, 168),
#    (14, 224, 168),
#    (8, 256, 256),
#    (8, 256, 256),
#    (8, 256, 214),
#    (8, 256, 214),
#    (8, 256, 216),
#    (8, 256, 216),
#    (9, 256, 216),
#    (9, 256, 216),
#    (6, 256, 216),
#    (6, 256, 216),
#    (17, 224, 154),
#    (17, 224, 154),
#    (16, 154, 224),
#    (16, 154, 224),
#    (6, 256, 208),
#    (6, 256, 208),
#    (12, 256, 208),
#    (12, 256, 208),
#    (15, 288, 184),
#    (15, 288, 184),
#    (7, 256, 192),
#    (7, 256, 192),
#    (8, 184, 256),
#    (8, 184, 256),
#    (16, 154, 224),
#    (16, 154, 224),
#    (6, 288, 264),
#    (6, 288, 264),
#    (7, 224, 154),
#    (7, 224, 154),
#    (8, 224, 180),
#    (8, 224, 180),
#    (15, 208, 174),
#    (15, 208, 174),
#    (10, 224, 180),
#    (10, 224, 180),
#    (10, 174, 208),
#    (10, 174, 208),
#    (14, 224, 180),
#    (14, 224, 180),
#    (18, 208, 174),
#    (18, 208, 174),
#    (8, 256, 216),
#    (8, 256, 216),
#    (7, 256, 216),
#    (7, 256, 216),
#    (16, 224, 154),
#    (16, 224, 154),
#    (8, 304, 216),
#    (8, 304, 216)],
#   'all_spacings': [array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.       ,  1.7578125,  1.7578125]),
#    array([10.       ,  1.7578125,  1.7578125]),
#    array([10.   ,  1.875,  1.875]),
#    array([10.   ,  1.875,  1.875]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.     ,  1.75781,  1.75781]),
#    array([10.     ,  1.75781,  1.75781]),
#    array([10.       ,  1.6796875,  1.6796875]),
#    array([10.       ,  1.6796875,  1.6796875]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.       ,  1.4453125,  1.4453125]),
#    array([10.       ,  1.4453125,  1.4453125]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.4453125,  1.4453125]),
#    array([10.       ,  1.4453125,  1.4453125]),
#    array([10.      ,  1.484375,  1.484375]),
#    array([10.      ,  1.484375,  1.484375]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([5.     , 1.67969, 1.67969]),
#    array([5.     , 1.67969, 1.67969]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.   ,  1.875,  1.875]),
#    array([10.   ,  1.875,  1.875]),
#    array([10.        ,  0.83333302,  0.83333302]),
#    array([10.        ,  0.83333302,  0.83333302]),
#    array([10.        ,  1.64061999,  1.64061999]),
#    array([10.        ,  1.64061999,  1.64061999]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.78570998,  1.78570998]),
#    array([10.        ,  1.78570998,  1.78570998]),
#    array([10.       ,  1.7578125,  1.7578125]),
#    array([10.       ,  1.7578125,  1.7578125]),
#    array([6.5       , 1.91963995, 1.91963995]),
#    array([6.5       , 1.91963995, 1.91963995]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.     ,  1.67969,  1.67969]),
#    array([10.     ,  1.67969,  1.67969]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.        ,  1.64061999,  1.64061999]),
#    array([10.        ,  1.64061999,  1.64061999]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.      ,  0.703125,  0.703125]),
#    array([10.      ,  0.703125,  0.703125]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.4453125,  1.4453125]),
#    array([10.       ,  1.4453125,  1.4453125]),
#    array([10.   ,  1.875,  1.875]),
#    array([10.   ,  1.875,  1.875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.       ,  1.3671875,  1.3671875]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.      ,  1.640625,  1.640625]),
#    array([10.      ,  1.640625,  1.640625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([5.        , 1.78570998, 1.78570998]),
#    array([5.        , 1.78570998, 1.78570998]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.     ,  1.40625,  1.40625]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.36719,  1.36719]),
#    array([10.     ,  1.75781,  1.75781]),
#    array([10.     ,  1.75781,  1.75781]),
#    array([5.        , 1.65179002, 1.65179002]),
#    array([5.        , 1.65179002, 1.65179002]),
#    array([5.        , 1.78570998, 1.78570998]),
#    array([5.        , 1.78570998, 1.78570998]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([5.     , 1.36719, 1.36719]),
#    array([5.     , 1.36719, 1.36719]),
#    array([5.        , 1.21528006, 1.21528006]),
#    array([5.        , 1.21528006, 1.21528006]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([10.     ,  1.44531,  1.44531]),
#    array([5.        , 1.65179002, 1.65179002]),
#    array([5.        , 1.65179002, 1.65179002]),
#    array([10.        ,  1.45833004,  1.45833004]),
#    array([10.        ,  1.45833004,  1.45833004]),
#    array([10.        ,  1.78570998,  1.78570998]),
#    array([10.        ,  1.78570998,  1.78570998]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([10.    ,  1.5625,  1.5625]),
#    array([5.        , 1.68269002, 1.68269002]),
#    array([5.        , 1.68269002, 1.68269002]),
#    array([7.    , 1.5625, 1.5625]),
#    array([7.    , 1.5625, 1.5625]),
#    array([5.        , 1.68269002, 1.68269002]),
#    array([5.        , 1.68269002, 1.68269002]),
#    array([5.    , 1.5625, 1.5625]),
#    array([5.    , 1.5625, 1.5625]),
#    array([5.        , 1.68269002, 1.68269002]),
#    array([5.        , 1.68269002, 1.68269002]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.        ,  1.48438001,  1.48438001]),
#    array([10.  ,  1.25,  1.25]),
#    array([10.  ,  1.25,  1.25]),
#    array([5.        , 1.78570998, 1.78570998]),
#    array([5.        , 1.78570998, 1.78570998]),
#    array([10.        ,  1.31579006,  1.31579006]),
#    array([10.        ,  1.31579006,  1.31579006])],
#   'all_classes': [1, 2, 3],
#   'modalities': {0: 'MRI'},
#   'intensityproperties': None,
#   'size_reductions': OrderedDict([('patient001_frame01', 1.0),
#                ('patient001_frame12', 1.0),
#                ('patient002_frame01', 0.9956896551724138),
#                ('patient002_frame12', 0.9956896551724138),
#                ('patient003_frame01', 0.99609375),
#                ('patient003_frame15', 0.99609375),
#                ('patient004_frame01', 1.0),
#                ('patient004_frame15', 1.0),
#                ('patient005_frame01', 0.99609375),
#                ('patient005_frame13', 0.99609375),
#                ('patient006_frame01', 0.9956896551724138),
#                ('patient006_frame16', 0.9956896551724138),
#                ('patient007_frame01', 0.9955357142857143),
#                ('patient007_frame07', 0.9955357142857143),
#                ('patient008_frame01', 0.995),
#                ('patient008_frame13', 0.995),
#                ('patient009_frame01', 1.0),
#                ('patient009_frame13', 1.0),
#                ('patient010_frame01', 1.0),
#                ('patient010_frame13', 1.0),
#                ('patient011_frame01', 1.0),
#                ('patient011_frame08', 1.0),
#                ('patient012_frame01', 1.0),
#                ('patient012_frame13', 1.0),
#                ('patient013_frame01', 1.0),
#                ('patient013_frame14', 1.0),
#                ('patient014_frame01', 1.0),
#                ('patient014_frame13', 1.0),
#                ('patient015_frame01', 1.0),
#                ('patient015_frame10', 1.0),
#                ('patient016_frame01', 1.0),
#                ('patient016_frame12', 1.0),
#                ('patient017_frame01', 1.0),
#                ('patient017_frame09', 1.0),
#                ('patient018_frame01', 1.0),
#                ('patient018_frame10', 1.0),
#                ('patient019_frame01', 1.0),
#                ('patient019_frame11', 1.0),
#                ('patient020_frame01', 1.0),
#                ('patient020_frame11', 1.0),
#                ('patient021_frame01', 0.99609375),
#                ('patient021_frame13', 0.99609375),
#                ('patient022_frame01', 1.0),
#                ('patient022_frame11', 1.0),
#                ('patient023_frame01', 1.0),
#                ('patient023_frame09', 1.0),
#                ('patient024_frame01', 0.9951923076923077),
#                ('patient024_frame09', 0.9951923076923077),
#                ('patient025_frame01', 0.99609375),
#                ('patient025_frame09', 0.99609375),
#                ('patient026_frame01', 0.99609375),
#                ('patient026_frame12', 0.99609375),
#                ('patient027_frame01', 1.0),
#                ('patient027_frame11', 1.0),
#                ('patient028_frame01', 0.99609375),
#                ('patient028_frame09', 0.99609375),
#                ('patient029_frame01', 0.99609375),
#                ('patient029_frame12', 0.99609375),
#                ('patient030_frame01', 0.9953703703703703),
#                ('patient030_frame12', 0.9953703703703703),
#                ('patient031_frame01', 1.0),
#                ('patient031_frame10', 1.0),
#                ('patient032_frame01', 0.9921875),
#                ('patient032_frame12', 0.9921875),
#                ('patient033_frame01', 1.0),
#                ('patient033_frame14', 1.0),
#                ('patient034_frame01', 1.0),
#                ('patient034_frame16', 1.0),
#                ('patient035_frame01', 1.0),
#                ('patient035_frame11', 1.0),
#                ('patient036_frame01', 1.0),
#                ('patient036_frame12', 1.0),
#                ('patient037_frame01', 1.0),
#                ('patient037_frame12', 1.0),
#                ('patient038_frame01', 1.0),
#                ('patient038_frame11', 1.0),
#                ('patient039_frame01', 1.0),
#                ('patient039_frame10', 1.0),
#                ('patient040_frame01', 1.0),
#                ('patient040_frame13', 1.0),
#                ('patient041_frame01', 1.0),
#                ('patient041_frame11', 1.0),
#                ('patient042_frame01', 0.9956896551724138),
#                ('patient042_frame16', 0.9956896551724138),
#                ('patient043_frame01', 1.0),
#                ('patient043_frame07', 1.0),
#                ('patient044_frame01', 1.0),
#                ('patient044_frame11', 1.0),
#                ('patient045_frame01', 1.0),
#                ('patient045_frame13', 1.0),
#                ('patient046_frame01', 1.0),
#                ('patient046_frame10', 1.0),
#                ('patient047_frame01', 1.0),
#                ('patient047_frame09', 1.0),
#                ('patient048_frame01', 1.0),
#                ('patient048_frame08', 1.0),
#                ('patient049_frame01', 1.0),
#                ('patient049_frame11', 1.0),
#                ('patient050_frame01', 1.0),
#                ('patient050_frame12', 1.0),
#                ('patient051_frame01', 1.0),
#                ('patient051_frame11', 1.0),
#                ('patient052_frame01', 1.0),
#                ('patient052_frame09', 1.0),
#                ('patient053_frame01', 1.0),
#                ('patient053_frame12', 1.0),
#                ('patient054_frame01', 1.0),
#                ('patient054_frame12', 1.0),
#                ('patient055_frame01', 1.0),
#                ('patient055_frame10', 1.0),
#                ('patient056_frame01', 1.0),
#                ('patient056_frame12', 1.0),
#                ('patient057_frame01', 1.0),
#                ('patient057_frame09', 1.0),
#                ('patient058_frame01', 1.0),
#                ('patient058_frame14', 1.0),
#                ('patient059_frame01', 1.0),
#                ('patient059_frame09', 1.0),
#                ('patient060_frame01', 1.0),
#                ('patient060_frame14', 1.0),
#                ('patient061_frame01', 0.9953703703703703),
#                ('patient061_frame10', 0.9953703703703703),
#                ('patient062_frame01', 1.0),
#                ('patient062_frame09', 1.0),
#                ('patient063_frame01', 1.0),
#                ('patient063_frame16', 1.0),
#                ('patient064_frame01', 1.0),
#                ('patient064_frame12', 1.0),
#                ('patient065_frame01', 0.9952380952380953),
#                ('patient065_frame14', 0.9952380952380953),
#                ('patient066_frame01', 1.0),
#                ('patient066_frame11', 1.0),
#                ('patient067_frame01', 0.99609375),
#                ('patient067_frame10', 0.99609375),
#                ('patient068_frame01', 1.0),
#                ('patient068_frame12', 1.0),
#                ('patient069_frame01', 1.0),
#                ('patient069_frame12', 1.0),
#                ('patient070_frame01', 1.0),
#                ('patient070_frame10', 1.0),
#                ('patient071_frame01', 1.0),
#                ('patient071_frame09', 1.0),
#                ('patient072_frame01', 1.0),
#                ('patient072_frame11', 1.0),
#                ('patient073_frame01', 1.0),
#                ('patient073_frame10', 1.0),
#                ('patient074_frame01', 1.0),
#                ('patient074_frame12', 1.0),
#                ('patient075_frame01', 1.0),
#                ('patient075_frame06', 1.0),
#                ('patient076_frame01', 1.0),
#                ('patient076_frame12', 1.0),
#                ('patient077_frame01', 1.0),
#                ('patient077_frame09', 1.0),
#                ('patient078_frame01', 1.0),
#                ('patient078_frame09', 1.0),
#                ('patient079_frame01', 1.0),
#                ('patient079_frame11', 1.0),
#                ('patient080_frame01', 1.0),
#                ('patient080_frame10', 1.0),
#                ('patient081_frame01', 1.0),
#                ('patient081_frame07', 1.0),
#                ('patient082_frame01', 1.0),
#                ('patient082_frame07', 1.0),
#                ('patient083_frame01', 1.0),
#                ('patient083_frame08', 1.0),
#                ('patient084_frame01', 1.0),
#                ('patient084_frame10', 1.0),
#                ('patient085_frame01', 1.0),
#                ('patient085_frame09', 1.0),
#                ('patient086_frame01', 1.0),
#                ('patient086_frame08', 1.0),
#                ('patient087_frame01', 1.0),
#                ('patient087_frame10', 1.0),
#                ('patient088_frame01', 1.0),
#                ('patient088_frame12', 1.0),
#                ('patient089_frame01', 1.0),
#                ('patient089_frame10', 1.0),
#                ('patient090_frame04', 1.0),
#                ('patient090_frame11', 1.0),
#                ('patient091_frame01', 1.0),
#                ('patient091_frame09', 1.0),
#                ('patient092_frame01', 1.0),
#                ('patient092_frame06', 1.0),
#                ('patient093_frame01', 1.0),
#                ('patient093_frame14', 1.0),
#                ('patient094_frame01', 1.0),
#                ('patient094_frame07', 1.0),
#                ('patient095_frame01', 1.0),
#                ('patient095_frame12', 1.0),
#                ('patient096_frame01', 1.0),
#                ('patient096_frame08', 1.0),
#                ('patient097_frame01', 1.0),
#                ('patient097_frame11', 1.0),
#                ('patient098_frame01', 1.0),
#                ('patient098_frame09', 1.0),
#                ('patient099_frame01', 1.0),
#                ('patient099_frame09', 1.0),
#                ('patient100_frame01', 1.0),
#                ('patient100_frame13', 1.0)])},
#  'list_of_npz_files': ['/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient001_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient001_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient002_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient002_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient003_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient003_frame15.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient004_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient004_frame15.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient005_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient005_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient006_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient006_frame16.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient007_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient007_frame07.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient008_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient008_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient009_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient009_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient010_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient010_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient011_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient011_frame08.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient012_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient012_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient013_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient013_frame14.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient014_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient014_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient015_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient015_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient016_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient016_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient017_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient017_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient018_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient018_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient019_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient019_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient020_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient020_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient021_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient021_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient022_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient022_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient023_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient023_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient024_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient024_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient025_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient025_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient026_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient026_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient027_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient027_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient028_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient028_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient029_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient029_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient030_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient030_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient031_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient031_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient032_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient032_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient033_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient033_frame14.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient034_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient034_frame16.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient035_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient035_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient036_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient036_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient037_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient037_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient038_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient038_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient039_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient039_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient040_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient040_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient041_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient041_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient042_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient042_frame16.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient043_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient043_frame07.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient044_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient044_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient045_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient045_frame13.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient046_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient046_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient047_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient047_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient048_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient048_frame08.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient049_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient049_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient050_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient050_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient051_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient051_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient052_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient052_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient053_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient053_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient054_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient054_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient055_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient055_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient056_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient056_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient057_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient057_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient058_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient058_frame14.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient059_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient059_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient060_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient060_frame14.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient061_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient061_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient062_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient062_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient063_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient063_frame16.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient064_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient064_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient065_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient065_frame14.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient066_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient066_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient067_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient067_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient068_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient068_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient069_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient069_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient070_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient070_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient071_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient071_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient072_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient072_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient073_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient073_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient074_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient074_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient075_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient075_frame06.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient076_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient076_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient077_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient077_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient078_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient078_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient079_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient079_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient080_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient080_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient081_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient081_frame07.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient082_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient082_frame07.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient083_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient083_frame08.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient084_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient084_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient085_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient085_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient086_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient086_frame08.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient087_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient087_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient088_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient088_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient089_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient089_frame10.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient090_frame04.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient090_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient091_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient091_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient092_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient092_frame06.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient093_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient093_frame14.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient094_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient094_frame07.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient095_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient095_frame12.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient096_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient096_frame08.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient097_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient097_frame11.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient098_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient098_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient099_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient099_frame09.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient100_frame01.npz',
#   '/home/lennartz/repos/nnUNet/data/nnUNet_raw_data_base/nnUNet_cropped_data/Task500_ACDC/patient100_frame13.npz'],
#  'original_spacings': [array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.       ,  1.7578125,  1.7578125]),
#   array([10.       ,  1.7578125,  1.7578125]),
#   array([10.   ,  1.875,  1.875]),
#   array([10.   ,  1.875,  1.875]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.     ,  1.75781,  1.75781]),
#   array([10.     ,  1.75781,  1.75781]),
#   array([10.       ,  1.6796875,  1.6796875]),
#   array([10.       ,  1.6796875,  1.6796875]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.       ,  1.4453125,  1.4453125]),
#   array([10.       ,  1.4453125,  1.4453125]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.4453125,  1.4453125]),
#   array([10.       ,  1.4453125,  1.4453125]),
#   array([10.      ,  1.484375,  1.484375]),
#   array([10.      ,  1.484375,  1.484375]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([5.     , 1.67969, 1.67969]),
#   array([5.     , 1.67969, 1.67969]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.   ,  1.875,  1.875]),
#   array([10.   ,  1.875,  1.875]),
#   array([10.        ,  0.83333302,  0.83333302]),
#   array([10.        ,  0.83333302,  0.83333302]),
#   array([10.        ,  1.64061999,  1.64061999]),
#   array([10.        ,  1.64061999,  1.64061999]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.78570998,  1.78570998]),
#   array([10.        ,  1.78570998,  1.78570998]),
#   array([10.       ,  1.7578125,  1.7578125]),
#   array([10.       ,  1.7578125,  1.7578125]),
#   array([6.5       , 1.91963995, 1.91963995]),
#   array([6.5       , 1.91963995, 1.91963995]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.     ,  1.67969,  1.67969]),
#   array([10.     ,  1.67969,  1.67969]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.        ,  1.64061999,  1.64061999]),
#   array([10.        ,  1.64061999,  1.64061999]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.      ,  0.703125,  0.703125]),
#   array([10.      ,  0.703125,  0.703125]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.4453125,  1.4453125]),
#   array([10.       ,  1.4453125,  1.4453125]),
#   array([10.   ,  1.875,  1.875]),
#   array([10.   ,  1.875,  1.875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.       ,  1.3671875,  1.3671875]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.      ,  1.640625,  1.640625]),
#   array([10.      ,  1.640625,  1.640625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([5.        , 1.78570998, 1.78570998]),
#   array([5.        , 1.78570998, 1.78570998]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.     ,  1.40625,  1.40625]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.36719,  1.36719]),
#   array([10.     ,  1.75781,  1.75781]),
#   array([10.     ,  1.75781,  1.75781]),
#   array([5.        , 1.65179002, 1.65179002]),
#   array([5.        , 1.65179002, 1.65179002]),
#   array([5.        , 1.78570998, 1.78570998]),
#   array([5.        , 1.78570998, 1.78570998]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([5.     , 1.36719, 1.36719]),
#   array([5.     , 1.36719, 1.36719]),
#   array([5.        , 1.21528006, 1.21528006]),
#   array([5.        , 1.21528006, 1.21528006]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([10.     ,  1.44531,  1.44531]),
#   array([5.        , 1.65179002, 1.65179002]),
#   array([5.        , 1.65179002, 1.65179002]),
#   array([10.        ,  1.45833004,  1.45833004]),
#   array([10.        ,  1.45833004,  1.45833004]),
#   array([10.        ,  1.78570998,  1.78570998]),
#   array([10.        ,  1.78570998,  1.78570998]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([10.    ,  1.5625,  1.5625]),
#   array([5.        , 1.68269002, 1.68269002]),
#   array([5.        , 1.68269002, 1.68269002]),
#   array([7.    , 1.5625, 1.5625]),
#   array([7.    , 1.5625, 1.5625]),
#   array([5.        , 1.68269002, 1.68269002]),
#   array([5.        , 1.68269002, 1.68269002]),
#   array([5.    , 1.5625, 1.5625]),
#   array([5.    , 1.5625, 1.5625]),
#   array([5.        , 1.68269002, 1.68269002]),
#   array([5.        , 1.68269002, 1.68269002]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.        ,  1.48438001,  1.48438001]),
#   array([10.  ,  1.25,  1.25]),
#   array([10.  ,  1.25,  1.25]),
#   array([5.        , 1.78570998, 1.78570998]),
#   array([5.        , 1.78570998, 1.78570998]),
#   array([10.        ,  1.31579006,  1.31579006]),
#   array([10.        ,  1.31579006,  1.31579006])],
#  'original_sizes': [(10, 256, 216),
#   (10, 256, 216),
#   (10, 256, 231),
#   (10, 256, 231),
#   (10, 255, 256),
#   (10, 255, 256),
#   (10, 256, 232),
#   (10, 256, 232),
#   (10, 216, 255),
#   (10, 216, 255),
#   (11, 256, 231),
#   (11, 256, 231),
#   (10, 223, 222),
#   (10, 223, 222),
#   (10, 256, 199),
#   (10, 256, 199),
#   (10, 256, 208),
#   (10, 256, 208),
#   (10, 256, 208),
#   (10, 256, 208),
#   (9, 256, 216),
#   (9, 256, 216),
#   (10, 256, 184),
#   (10, 256, 184),
#   (10, 256, 216),
#   (10, 256, 216),
#   (10, 216, 256),
#   (10, 216, 256),
#   (9, 216, 256),
#   (9, 216, 256),
#   (10, 256, 192),
#   (10, 256, 192),
#   (9, 256, 216),
#   (9, 256, 216),
#   (8, 256, 216),
#   (8, 256, 216),
#   (11, 256, 216),
#   (11, 256, 216),
#   (8, 256, 208),
#   (8, 256, 208),
#   (10, 255, 240),
#   (10, 255, 240),
#   (7, 256, 200),
#   (7, 256, 200),
#   (9, 256, 216),
#   (9, 256, 216),
#   (8, 256, 207),
#   (8, 256, 207),
#   (9, 255, 256),
#   (9, 255, 256),
#   (10, 255, 216),
#   (10, 255, 216),
#   (10, 256, 216),
#   (10, 256, 216),
#   (10, 255, 224),
#   (10, 255, 224),
#   (11, 255, 192),
#   (11, 255, 192),
#   (10, 256, 215),
#   (10, 256, 215),
#   (10, 256, 216),
#   (10, 256, 216),
#   (10, 254, 240),
#   (10, 254, 240),
#   (10, 256, 216),
#   (10, 256, 216),
#   (10, 256, 224),
#   (10, 256, 224),
#   (13, 256, 208),
#   (13, 256, 208),
#   (8, 256, 216),
#   (8, 256, 216),
#   (7, 256, 216),
#   (7, 256, 216),
#   (8, 384, 276),
#   (8, 384, 276),
#   (9, 256, 208),
#   (9, 256, 208),
#   (10, 256, 208),
#   (10, 256, 208),
#   (6, 224, 154),
#   (6, 224, 154),
#   (9, 256, 231),
#   (9, 256, 231),
#   (12, 224, 174),
#   (12, 224, 174),
#   (9, 216, 256),
#   (9, 216, 256),
#   (8, 256, 208),
#   (8, 256, 208),
#   (9, 216, 256),
#   (9, 216, 256),
#   (9, 208, 256),
#   (9, 208, 256),
#   (8, 256, 208),
#   (8, 256, 208),
#   (7, 216, 256),
#   (7, 216, 256),
#   (10, 256, 248),
#   (10, 256, 248),
#   (10, 256, 224),
#   (10, 256, 224),
#   (8, 256, 216),
#   (8, 256, 216),
#   (7, 256, 216),
#   (7, 256, 216),
#   (8, 256, 216),
#   (8, 256, 216),
#   (9, 216, 256),
#   (9, 216, 256),
#   (9, 256, 216),
#   (9, 256, 216),
#   (8, 512, 428),
#   (8, 512, 428),
#   (9, 256, 216),
#   (9, 256, 216),
#   (9, 216, 256),
#   (9, 216, 256),
#   (9, 256, 216),
#   (9, 256, 216),
#   (9, 256, 215),
#   (9, 256, 215),
#   (10, 216, 256),
#   (10, 216, 256),
#   (8, 176, 256),
#   (8, 176, 256),
#   (10, 256, 216),
#   (10, 256, 216),
#   (8, 224, 209),
#   (8, 224, 209),
#   (9, 256, 240),
#   (9, 256, 240),
#   (10, 216, 255),
#   (10, 216, 255),
#   (7, 208, 256),
#   (7, 208, 256),
#   (7, 256, 216),
#   (7, 256, 216),
#   (6, 256, 208),
#   (6, 256, 208),
#   (10, 256, 192),
#   (10, 256, 192),
#   (8, 256, 216),
#   (8, 256, 216),
#   (7, 256, 208),
#   (7, 256, 208),
#   (8, 256, 256),
#   (8, 256, 256),
#   (14, 224, 168),
#   (14, 224, 168),
#   (8, 256, 256),
#   (8, 256, 256),
#   (8, 256, 214),
#   (8, 256, 214),
#   (8, 256, 216),
#   (8, 256, 216),
#   (9, 256, 216),
#   (9, 256, 216),
#   (6, 256, 216),
#   (6, 256, 216),
#   (17, 224, 154),
#   (17, 224, 154),
#   (16, 154, 224),
#   (16, 154, 224),
#   (6, 256, 208),
#   (6, 256, 208),
#   (12, 256, 208),
#   (12, 256, 208),
#   (15, 288, 184),
#   (15, 288, 184),
#   (7, 256, 192),
#   (7, 256, 192),
#   (8, 184, 256),
#   (8, 184, 256),
#   (16, 154, 224),
#   (16, 154, 224),
#   (6, 288, 264),
#   (6, 288, 264),
#   (7, 224, 154),
#   (7, 224, 154),
#   (8, 224, 180),
#   (8, 224, 180),
#   (15, 208, 174),
#   (15, 208, 174),
#   (10, 224, 180),
#   (10, 224, 180),
#   (10, 174, 208),
#   (10, 174, 208),
#   (14, 224, 180),
#   (14, 224, 180),
#   (18, 208, 174),
#   (18, 208, 174),
#   (8, 256, 216),
#   (8, 256, 216),
#   (7, 256, 216),
#   (7, 256, 216),
#   (16, 224, 154),
#   (16, 224, 154),
#   (8, 304, 216),
#   (8, 304, 216)],
#  'preprocessed_data_folder': '/home/lennartz/repos/nnUNet/data/nnUNet_preprocessed/Task500_ACDC',
#  'num_classes': 3,
#  'all_classes': [1, 2, 3],
#  'base_num_features': 32,
#  'use_mask_for_norm': OrderedDict([(0, False)]),
#  'keep_only_largest_region': None,
#  'min_region_size_per_class': None,
#  'min_size_per_class': None,
#  'transpose_forward': [0, 1, 2],
#  'transpose_backward': [0, 1, 2],
#  'data_identifier': 'nnUNetData_plans_v2.1_2D',
#  'plans_per_stage': {0: {'batch_size': 56,
#    'num_pool_per_axis': [6, 5],
#    'patch_size': array([256, 224]),
#    'median_patient_size_in_voxels': array([  9, 237, 208]),
#    'current_spacing': array([10.    ,  1.5625,  1.5625]),
#    'original_spacing': array([10.    ,  1.5625,  1.5625]),
#    'pool_op_kernel_sizes': [[2, 2], [2, 2], [2, 2], [2, 2], [2, 2], [2, 1]],
#    'conv_kernel_sizes': [[3, 3],
#     [3, 3],
#     [3, 3],
#     [3, 3],
#     [3, 3],
#     [3, 3],
#     [3, 3]],
#    'do_dummy_2D_data_aug': False}},
#  'preprocessor_name': 'PreprocessorFor2D'}

# %%
pkl_file
# Out:
# '../../../../nnUNet/data/nnUNet_preprocessed/Task500_ACDC/nnUNetPlansv2.1_plans_2D.pkl'

# %%
train_transforms = [t for t in train_loader.transform.transforms]
valid_transforms = [t for t in valid_loader.transform.transforms]

# %%
import pprint
pprint.pprint(valid_transforms)
# Out:
# [RemoveLabelTransform( output_key = 'seg', input_key = 'seg', replace_with = 0, remove_label = -1 ),
#  SegChannelSelectionTransform( label_key = 'seg', channels = [0], keep_discarded = False ),
#  RenameTransform( delete_old = True, out_key = 'target', in_key = 'seg' ),
#  DownsampleSegForDSTransform2( axes = None, output_key = 'target', input_key = 'target', order = 0, ds_scales = [[1, 1, 1], [0.5, 0.5], [0.25, 0.25], [0.125, 0.125], [0.0625, 0.0625], [0.03125, 0.03125]] ),
#  NumpyToTensor( keys = ['data', 'target'], cast_to = 'float' )]

# %%
valid_transforms
# Out:
# [<batchgenerators.transforms.local_transforms.BrightnessGradientAdditiveTransform at 0x7f7ce35d8e20>,
#  <batchgenerators.transforms.local_transforms.LocalGammaTransform at 0x7f7dd43df9d0>,
#  <batchgenerators.transforms.local_transforms.LocalSmoothingTransform at 0x7f7ce0394af0>,
#  <batchgenerators.transforms.local_transforms.LocalContrastTransform at 0x7f7ce0394a90>,
#  RemoveLabelTransform( output_key = 'seg', input_key = 'seg', replace_with = 0, remove_label = -1 ),
#  RenameTransform( delete_old = True, out_key = 'target', in_key = 'seg' ),
#  NumpyToTensor( keys = ['data', 'target'], cast_to = 'float' )]

# %%
torch.save(train_transforms, 'test.pt')

# %%
test = torch.load('test.pt')

# %%
[SegChannelSelectionTransform( label_key = 'seg', channels = [0], keep_discarded = False ),
 SpatialTransform( independent_scale_for_each_axis = False, p_rot_per_sample = 0.2, p_scale_per_sample = 0.2, p_el_per_sample = 0.2, data_key = 'data', label_key = 'seg', patch_size = array([256, 224]), patch_center_dist_from_border = None, do_elastic_deform = False, alpha = (0.0, 200.0), sigma = (9.0, 13.0), do_rotation = True, angle_x = (-3.141592653589793, 3.141592653589793), angle_y = (-0.0, 0.0), angle_z = (-0.0, 0.0), do_scale = True, scale = (0.7, 1.4), border_mode_data = 'constant', border_cval_data = 0, order_data = 3, border_mode_seg = 'constant', border_cval_seg = -1, order_seg = 1, random_crop = False, p_rot_per_axis = 1, p_independent_scale_per_axis = 1 ),
 GaussianNoiseTransform( p_per_sample = 0.1, data_key = 'data', noise_variance = (0, 0.1), p_per_channel = 1, per_channel = False ),
 GaussianBlurTransform( p_per_sample = 0.2, different_sigma_per_channel = True, p_per_channel = 0.5, data_key = 'data', blur_sigma = (0.5, 1.0), different_sigma_per_axis = False, p_isotropic = 0 ),
 BrightnessMultiplicativeTransform( p_per_sample = 0.15, data_key = 'data', multiplier_range = (0.75, 1.25), per_channel = True ),
 ContrastAugmentationTransform( p_per_sample = 0.15, data_key = 'data', contrast_range = (0.75, 1.25), preserve_range = True, per_channel = True, p_per_channel = 1 ),
 SimulateLowResolutionTransform( order_upsample = 3, order_downsample = 0, channels = None, per_channel = True, p_per_channel = 0.5, p_per_sample = 0.25, data_key = 'data', zoom_range = (0.5, 1), ignore_axes = None ),
 GammaTransform( p_per_sample = 0.1, retain_stats = True, per_channel = True, data_key = 'data', gamma_range = (0.7, 1.5), invert_image = True ),
 GammaTransform( p_per_sample = 0.3, retain_stats = True, per_channel = True, data_key = 'data', gamma_range = (0.7, 1.5), invert_image = False ),
 MirrorTransform( p_per_sample = 1, data_key = 'data', label_key = 'seg', axes = (0, 1) ),
 MaskTransform( dct_for_where_it_was_used = OrderedDict([(0, False)]), seg_key = 'seg', data_key = 'data', set_outside_to = 0, mask_idx_in_seg = 0 ),
 RemoveLabelTransform( output_key = 'seg', input_key = 'seg', replace_with = 0, remove_label = -1 ),
 RenameTransform( delete_old = True, out_key = 'target', in_key = 'seg' ),
 DownsampleSegForDSTransform2( axes = None, output_key = 'target', input_key = 'target', order = 0, ds_scales = [[1, 1, 1], [0.5, 0.5], [0.25, 0.25], [0.125, 0.125], [0.0625, 0.0625], [0.03125, 0.03125]] ),
 NumpyToTensor( keys = ['data', 'target'], cast_to = 'float' )]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 [SegChannelSelectionTransform( label_key = 'seg', channels = [0], keep_discarded = False ),
#       2  SpatialTransform( independent_scale_for_each_axis = False, p_rot_per_sample = 0.2, p_scale_per_sample = 0.2, p_el_per_sample = 0.2, data_key = 'data', label_key = 'seg', patch_size = array([256, 224]), patch_center_dist_from_border = None, do_elastic_deform = False, alpha = (0.0, 200.0), sigma = (9.0, 13.0), do_rotation = True, angle_x = (-3.141592653589793, 3.141592653589793), angle_y = (-0.0, 0.0), angle_z = (-0.0, 0.0), do_scale = True, scale = (0.7, 1.4), border_mode_data = 'constant', border_cval_data = 0, order_data = 3, border_mode_seg = 'constant', border_cval_seg = -1, order_seg = 1, random_crop = False, p_rot_per_axis = 1, p_independent_scale_per_axis = 1 ),
#       3  GaussianNoiseTransform( p_per_sample = 0.1, data_key = 'data', noise_variance = (0, 0.1), p_per_channel = 1, per_channel = False ),
#       4  GaussianBlurTransform( p_per_sample = 0.2, different_sigma_per_channel = True, p_per_channel = 0.5, data_key = 'data', blur_sigma = (0.5, 1.0), different_sigma_per_axis = False, p_isotropic = 0 ),
#       5  BrightnessMultiplicativeTransform( p_per_sample = 0.15, data_key = 'data', multiplier_range = (0.75, 1.25), per_channel = True ),
#       6  ContrastAugmentationTransform( p_per_sample = 0.15, data_key = 'data', contrast_range = (0.75, 1.25), preserve_range = True, per_channel = True, p_per_channel = 1 ),
#       7  SimulateLowResolutionTransform( order_upsample = 3, order_downsample = 0, channels = None, per_channel = True, p_per_channel = 0.5, p_per_sample = 0.25, data_key = 'data', zoom_range = (0.5, 1), ignore_axes = None ),
#       8  GammaTransform( p_per_sample = 0.1, retain_stats = True, per_channel = True, data_key = 'data', gamma_range = (0.7, 1.5), invert_image = True ),
#       9  GammaTransform( p_per_sample = 0.3, retain_stats = True, per_channel = True, data_key = 'data', gamma_range = (0.7, 1.5), invert_image = False ),
#      10  MirrorTransform( p_per_sample = 1, data_key = 'data', label_key = 'seg', axes = (0, 1) ),
#      11  MaskTransform( dct_for_where_it_was_used = OrderedDict([(0, False)]), seg_key = 'seg', data_key = 'data', set_outside_to = 0, mask_idx_in_seg = 0 ),
#      12  RemoveLabelTransform( output_key = 'seg', input_key = 'seg', replace_with = 0, remove_label = -1 ),
#      13  RenameTransform( delete_old = True, out_key = 'target', in_key = 'seg' ),
#      14  DownsampleSegForDSTransform2( axes = None, output_key = 'target', input_key = 'target', order = 0, ds_scales = [[1, 1, 1], [0.5, 0.5], [0.25, 0.25], [0.125, 0.125], [0.0625, 0.0625], [0.03125, 0.03125]] ),
#      15  NumpyToTensor( keys = ['data', 'target'], cast_to = 'float' )]
#
# NameError: name 'SegChannelSelectionTransform' is not defined

# %%
from augment import nnUNet_augmentations
